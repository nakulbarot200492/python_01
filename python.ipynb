# %%
# Python Assignment

# 1. Who developed Python Programming Language?
print("1. Python was developed by Guido van Rossum.")

# 2. Which type of Programming does Python support?
print("2. Python supports multiple programming paradigms, including:")
print("   - Procedural programming")
print("   - Object-oriented programming")
print("   - Functional programming")

# 3. Is Python case sensitive when dealing with identifiers?
print("3. Yes, Python is case-sensitive when dealing with identifiers.")

# 4. What is the correct extension of the Python file?
print("4. The correct extension for a Python file is .py")

# 5. Is Python code compiled or interpreted?
print("5. Python is an interpreted language, although it goes through a compilation step to byte code internally.")

# 6. Name a few blocks of code used to define in Python language?
print("6. Some code blocks used in Python include:")
print("   - Function blocks (def)")
print("   - Class blocks (class)")
print("   - Conditional blocks (if, elif, else)")
print("   - Loop blocks (for, while)")
print("   - Try/except blocks for exception handling")

# 7. State a character used to give single-line comments in Python?
print("7. The # symbol is used for single-line comments in Python.")

# 8. Mention functions which can help us to find the version of python that we are currently working on?
print("8. Functions to find Python version:")
print("   - python --version (in terminal)")
print("   - sys.version")
print("   - platform.python_version()")

# Demonstration of sys.version and platform.python_version()
import sys
import platform

print(f"   Current Python version (sys.version): {sys.version}")
print(f"   Current Python version (platform.python_version()): {platform.python_version()}")

# 9. Python supports the creation of anonymous functions at runtime, using a construct called
print("9. Python supports anonymous functions through lambda expressions.")

# Example of a lambda function
square = lambda x: x**2
print(f"   Example: square of 5 using lambda function: {square(5)}")

# 10. What does pip stand for python?
print("10. pip stands for 'Pip Installs Packages' or 'Pip Installs Python'.")

# 11. Mention a few built-in functions in python?
print("11. Some built-in functions in Python:")
built_in_functions = ["print()", "len()", "type()", "int()", "str()", "list()", "dict()", "range()", "input()"]
for func in built_in_functions:
    print(f"    - {func}")

# 12. What is the maximum possible length of an identifier in Python?
print("12. An identifier in Python can have a maximum length of 79 characters.")

# 13. What are the benefits of using Python?
print("13. Benefits of using Python:")
benefits = [
    "Easy to learn and read",
    "Versatile and flexible",
    "Large standard library",
    "Strong community support",
    "Cross-platform compatibility",
    "Extensive third-party packages"
]
for benefit in benefits:
    print(f"    - {benefit}")

# 14. How is memory managed in Python?
print("14. Memory management in Python:")
print("    - Handled automatically through a private heap space")
print("    - Python memory manager handles memory allocation and deallocation")
print("    - Uses garbage collection to free up memory from objects no longer in use")

# 15. How to install Python on Windows and set path variables?
print("15. Installing Python on Windows and setting path variables:")
steps = [
    "Download the Python installer from python.org",
    "Run the installer, checking 'Add Python to PATH'",
    "If you didn't check that option, you can manually add Python to PATH:",
    "  - Right-click on 'This PC' and go to Properties",
    "  - Click on 'Advanced system settings'",
    "  - Click on 'Environment Variables'",
    "  - Under System Variables, find and select 'Path', then click 'Edit'",
    "  - Click 'New' and add the path to your Python installation"
]
for i, step in enumerate(steps, 1):
    print(f"    {i}. {step}")

# 16. Is indentation required in python?
print("16. Yes, indentation is required in Python. It is used to define code blocks and is a fundamental part of Python's syntax.")

# Demonstration of indentation
def example_function():
    if True:
        print("    This line is indented and part of the if block")
    print("    This line is indented and part of the function block")
print("    This line is not indented and outside the function block")

example_function()
# Out:
# 1. Python was developed by Guido van Rossum.
# 2. Python supports multiple programming paradigms, including:
#    - Procedural programming
#    - Object-oriented programming
#    - Functional programming
# 3. Yes, Python is case-sensitive when dealing with identifiers.
# 4. The correct extension for a Python file is .py
# 5. Python is an interpreted language, although it goes through a compilation step to byte code internally.
# 6. Some code blocks used in Python include:
#    - Function blocks (def)
#    - Class blocks (class)
#    - Conditional blocks (if, elif, else)
#    - Loop blocks (for, while)
#    - Try/except blocks for exception handling
# 7. The # symbol is used for single-line comments in Python.
# 8. Functions to find Python version:
#    - python --version (in terminal)
#    - sys.version
#    - platform.python_version()
#    Current Python version (sys.version): 3.10.8 | packaged by conda-forge | (main, Nov 22 2022, 08:26:04) [GCC 10.4.0]
# ...
